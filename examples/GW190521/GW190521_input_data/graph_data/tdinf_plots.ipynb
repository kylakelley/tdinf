# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# import csv

# total_mass = []
# mass_ratio = []
# luminosity_distance = []
# inclination = []
# spin1_magnitude = []
# spin2_magnitude = []


# with open('full_0.0seconds.dat') as f:
#     reader = csv.reader(f, delimiter=" ")
#     next(reader)
    
#     for line in reader:
#         line = [x for x in line if x]
#         total_mass.append(float(line[0]))
#         mass_ratio.append(float(line[1]))
#         luminosity_distance.append(float(line[2]))
#         inclination.append (float(line[3]))
#         spin1_magnitude.append (float(line[4]))
#         spin2_magnitude.append (float(line[5]))

total_mass, mass_ratio, luminosity_distance, inclination, spin1_magnitude, spin2_magnitude =np.loadtxt("full_0.0seconds.dat", skiprows=1, unpack=True, usecols=(0, 1, 2, 3, 4, 5))

# %%
plt.hist(total_mass, bins=100, density=True)
plt.xlabel("Total Mass")
plt.ylabel("Density")
plt.show()

# %%
plt.hist(mass_ratio, bins=100, density=True)
plt.xlabel("Mass Ratio")
plt.ylabel("Density")
plt.show()

# %%
plt.hist(luminosity_distance, bins=100, density=True)
plt.xlabel("Luminosity distance")
plt.ylabel("Density")
plt.show()

# %%
plt.hist(inclination, bins=100, density=True)
plt.xlabel("Inclination")
plt.ylabel("Density")
plt.show()

# %%
plt.hist(spin1_magnitude, bins=100, density=True)
plt.xlabel("Spin 1 Magnitude")
plt.ylabel("Density")
plt.show()

# %%
plt.hist(spin2_magnitude, bins=100, density=True)
plt.xlabel("Spin 2 Magnitude")
plt.ylabel("Density")
plt.show()

# %%
plt.scatter(luminosity_distance, inclination)
plt.show()
