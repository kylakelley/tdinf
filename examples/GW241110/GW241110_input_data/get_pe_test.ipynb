# %%
import sys
sys.path.insert(0, '/../')  # wherever tdinf lives
import tdinf.utils as utils

samples = utils.get_pe_samples('GW241110_124123-combined_PEDataRelease.h5')
print(type(samples))
print(samples.dtype.names)
# Out:
# /Users/kylakelley/Documents/Research/tdinf/tdinf/utils/io.py:1: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal
# <class 'numpy.ndarray'>
# ...

# %%
import tdinf.utils as utils

path_dict = {
    'H1': 'H-H1_GWOSC_O4b_16KHZ_R1-1415274496-4096.hdf5',
    'L1': 'L-L1_GWOSC_O4b_16KHZ_R1-1415274496-4096.hdf5',
    'V1': 'V-V1_GWOSC_O4b_16KHZ_R1-1415274496-4096.hdf5'
}

raw_time_dict, raw_data_dict = utils.load_raw_data(path_dict, ifos=['H1', 'L1', 'V1'], verbose=True)

for ifo in ['H1', 'L1', 'V1']:
    print(f'{ifo}: {len(raw_data_dict[ifo])} samples, t0={raw_time_dict[ifo][0]:.1f}')
# Out:
# Raw H1 data sampled at 16384.0 Hz
# Raw L1 data sampled at 16384.0 Hz
# Raw V1 data sampled at 16384.0 Hz
# H1: 67108864 samples, t0=1415274496.0
# L1: 67108864 samples, t0=1415274496.0
# V1: 67108864 samples, t0=1415274496.0
