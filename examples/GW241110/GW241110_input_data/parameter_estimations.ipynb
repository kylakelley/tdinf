# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
f = h5py.File("GW241110_posterior_samples_combined.h5")
print(list(f.keys()))
# Out:
# ['C00:IMRPhenomXO4a', 'C00:IMRPhenomXPHM-SpinTaylor', 'C00:Mixed', 'C00:SEOBNRv5PHM', 'history', 'version']

# %%
list(f['C00:IMRPhenomXO4a'].keys())
# Out:
# ['approximant',
#  'calibration_envelope',
#  'config_file',
#  'description',
#  'injection_data',
#  'meta_data',
#  'posterior_samples',
#  'priors',
#  'psds',
#  'version']

# %%
group = f['C00:IMRPhenomXO4a']
print(list(group.keys()))
# Out:
# ['approximant', 'calibration_envelope', 'config_file', 'description', 'injection_data', 'meta_data', 'posterior_samples', 'priors', 'psds', 'version']

# %%
times = group['meta_data']['meta_data']
print(list(times.keys()))
f_final = times['f_final'][:]
f_start = times['f_start'][:]
# Out:
# ['approximant', 'backward_spin_evolution', 'cosmology', 'delta_f', 'f_final', 'f_low', 'f_ref', 'f_start', 'final_mass_NR_fits', 'final_spin_NR_fits', 'forward_spin_evolution', 'multipole_snr', 'peak_luminosity_NR_fits', 'precessing_snr']

# %%
print(f_final)
print(f_start)
# Out:
# [1792.]
# [10.]

# %%
samples = group['posterior_samples']
samples.dtype.names
# Out:
# ('H1_log_likelihood',
#  'H1_matched_filter_snr',
#  'H1_optimal_snr',
#  'L1_log_likelihood',
#  'L1_matched_filter_snr',
#  'L1_optimal_snr',
#  'L1_time',
#  'V1_log_likelihood',
#  'V1_matched_filter_snr',
#  'V1_optimal_snr',
#  'a_1',
#  'a_2',
#  'azimuth',
#  'chi_1_in_plane',
#  'chi_2_in_plane',
#  'chi_eff',
#  'chi_p',
#  'chirp_mass',
#  'chirp_mass_source',
#  'comoving_distance',
#  'cos_tilt_1',
#  'cos_tilt_2',
#  'dec',
#  'geocent_time',
#  'iota',
#  'log_likelihood',
#  'log_prior',
#  'luminosity_distance',
#  'mass_1',
#  'mass_1_source',
#  'mass_2',
#  'mass_2_source',
#  'mass_ratio',
#  'phase',
#  'phi_1',
#  'phi_12',
#  'phi_2',
#  'phi_jl',
#  'psi',
#  'ra',
#  'recalib_H1_amplitude_0',
#  'recalib_H1_amplitude_1',
#  'recalib_H1_amplitude_2',
#  'recalib_H1_amplitude_3',
#  'recalib_H1_amplitude_4',
#  'recalib_H1_amplitude_5',
#  'recalib_H1_amplitude_6',
#  'recalib_H1_amplitude_7',
#  'recalib_H1_amplitude_8',
#  'recalib_H1_amplitude_9',
# ...

# %%
total_mass_post = samples["total_mass_source"][:]
mass_ratio_post = samples["mass_ratio"][:]
spin_magnitude_1_post = samples["a_1"][:]
spin_magnitude_2_post = samples["a_2"][:]
luminosity_distance_post = samples["luminosity_distance"]
chi_eff_post = samples["chi_eff"]

# %%
plt.hist(total_mass_post, bins=100, density=True, label="posterior")
plt.xlabel(r"Mass ($M_{\odot}$)")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
plt.hist(mass_ratio_post, bins=100, density=True, label="posterior")
plt.xlabel("Mass Ratio")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
plt.hist(spin_magnitude_1_post, bins=100, density=True, label="posterior")
plt.xlabel("Spin Magnitude")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
plt.hist(spin_magnitude_2_post, bins=100, density=True, label="posterior")
plt.xlabel("Spin Magnitude")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
plt.hist(luminosity_distance_post, bins=100, density=True, label="posterior")
plt.xlabel("Luminosity Distance")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
plt.hist(chi_eff_post, bins=100, density=True, label="posterior")
plt.xlabel("Chi Effective")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
group2 = f['C00:IMRPhenomXPHM-SpinTaylor']
samples2 = group2['posterior_samples']

group3 = f['C00:SEOBNRv5PHM']
samples3 = group3['posterior_samples']

# %%
total_mass_post2 = samples2["total_mass_source"][:]
mass_ratio_post2 = samples2["mass_ratio"][:]
spin_magnitude_1_post2 = samples2["a_1"][:]
spin_magnitude_2_post2 = samples2["a_2"][:]
luminosity_distance_post2 = samples2["luminosity_distance"]
chi_eff_post2 = samples2["chi_eff"]

redshift = samples["redshift"]
redshift2 = samples2["redshift"]
redshift3 = samples3["redshift"]

total_mass_post3 = samples3["total_mass_source"][:]
mass_ratio_post3 = samples3["mass_ratio"][:]
spin_magnitude_1_post3 = samples3["a_1"][:]
spin_magnitude_2_post3 = samples3["a_2"][:]
luminosity_distance_post3 = samples3["luminosity_distance"]
chi_eff_post3 = samples3["chi_eff"]

# %%
print(list(group2.keys()), list(group3.keys()))
# Out:
# ['approximant', 'calibration_envelope', 'config_file', 'description', 'injection_data', 'meta_data', 'posterior_samples', 'priors', 'psds', 'version'] ['approximant', 'calibration_envelope', 'config_file', 'description', 'injection_data', 'meta_data', 'posterior_samples', 'priors', 'psds', 'version']

# %%
print(list(group2['config_file'].attrs), list(group2['config_file'].attrs))
# Out:
# [] []

# %%
plt.hist(total_mass_post, bins=100, density=True, alpha=.5, label="IMRPhenomXO4a")
plt.hist(total_mass_post2, bins=100, density=True, alpha=.5, label="IMRPhenomXPHM-SpinTaylor")
plt.hist(total_mass_post3, bins=100, density=True, alpha=.5, label="SEOBNRv5PHM")
plt.xlabel(r"Total Mass ($M_{\odot}$)")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
np.median(total_mass_post2)
# Out:
# np.float64(24.973635790119566)

# %%
plt.hist(total_mass_post*(1+redshift), bins=100, density=True, alpha=.5, label="IMRPhenomXO4a")
plt.hist(total_mass_post2*(1+redshift2), bins=100, density=True, alpha=.5, label="IMRPhenomXPHM-SpinTaylor")
plt.hist(total_mass_post3*(1+redshift3), bins=100, density=True, alpha=.5, label="SEOBNRv5PHM")
plt.xlabel(r"Total Mass ($M_{\odot}$)")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
plt.hist(mass_ratio_post, bins=100, density=True, alpha=.5, label="IMRPhenomXO4a")
plt.hist(mass_ratio_post2, bins=100, density=True, alpha=.5, label="IMRPhenomXPHM-SpinTaylor")
plt.hist(mass_ratio_post3, bins=100, density=True, alpha=.5, label="SEOBNRv5PHM")
plt.xlabel("Mass Ratio")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
plt.hist(spin_magnitude_1_post, bins=100, density=True, alpha=.5, label="IMRPhenomXO4a")
plt.hist(spin_magnitude_1_post2, bins=100, density=True, alpha=.5, label="IMRPhenomXPHM-SpinTaylor")
plt.hist(spin_magnitude_1_post3, bins=100, density=True, alpha=.5, label="SEOBNRv5PHM")
plt.xlabel("Spin Magnitude 1")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
plt.hist(spin_magnitude_2_post, bins=100, density=True, alpha=.5, label="IMRPhenomXO4a")
plt.hist(spin_magnitude_2_post2, bins=100, density=True, alpha=.5, label="IMRPhenomXPHM-SpinTaylor")
plt.hist(spin_magnitude_2_post3, bins=100, density=True, alpha=.5, label="SEOBNRv5PHM")
plt.xlabel("Spin Magnitude 2")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
plt.hist(luminosity_distance_post, bins=100, density=True, alpha=.5, label="IMRPhenomXO4a")
plt.hist(luminosity_distance_post2, bins=100, density=True, alpha=.5, label="IMRPhenomXPHM-SpinTaylor")
plt.hist(luminosity_distance_post3, bins=100, density=True, alpha=.5, label="SEOBNRv5PHM")
plt.xlabel("Luminosity Distance")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
plt.hist(chi_eff_post, bins=100, density=True, alpha=.5, label="IMRPhenomXO4a")
plt.hist(chi_eff_post2, bins=100, density=True, alpha=.5, label="IMRPhenomXPHM-SpinTaylor")
plt.hist(chi_eff_post3, bins=100, density=True, alpha=.5, label="SEOBNRv5PHM")
plt.xlabel("Chi Effective")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
psds = group2['psds']
print(list(psds.keys()))
# Out:
# ['H1', 'L1', 'V1']

# %%
H1_psd = psds['H1'][:]
np.savetxt('H1_psd.dat', H1_psd)

# %%
L1_psd = psds['L1'][:]
np.savetxt('L1_psd.dat', L1_psd)

# %%
V1_psd = psds['V1'][:]
np.savetxt('V1_psd.dat', V1_psd)
