# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt

f = h5py.File('PEDataRelease_mixed_cosmo.h5')

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['C01:IMRPhenomXPHM', 'C01:Mixed', 'C01:SEOBNRv4PHM', 'history', 'version']>

# %%
f['C01:IMRPhenomXPHM'].keys()
# Out:
# <KeysViewHDF5 ['approximant', 'calibration_envelope', 'config_file', 'description', 'injection_data', 'meta_data', 'posterior_samples', 'priors', 'psds', 'skymap', 'version']>

# %%
samples = f['C01:IMRPhenomXPHM']['posterior_samples']
samples2 = f['C01:Mixed']['posterior_samples']
samples3 = f['C01:SEOBNRv4PHM']['posterior_samples']

# %%
samples.dtype.names
# Out:
# ('chirp_mass',
#  'mass_ratio',
#  'a_1',
#  'a_2',
#  'tilt_1',
#  'tilt_2',
#  'phi_12',
#  'phi_jl',
#  'theta_jn',
#  'psi',
#  'phase',
#  'azimuth',
#  'zenith',
#  'recalib_H1_amplitude_0',
#  'recalib_H1_amplitude_1',
#  'recalib_H1_amplitude_2',
#  'recalib_H1_amplitude_3',
#  'recalib_H1_amplitude_4',
#  'recalib_H1_amplitude_5',
#  'recalib_H1_amplitude_6',
#  'recalib_H1_amplitude_7',
#  'recalib_H1_amplitude_8',
#  'recalib_H1_amplitude_9',
#  'recalib_H1_phase_0',
#  'recalib_H1_phase_1',
#  'recalib_H1_phase_2',
#  'recalib_H1_phase_3',
#  'recalib_H1_phase_4',
#  'recalib_H1_phase_5',
#  'recalib_H1_phase_6',
#  'recalib_H1_phase_7',
#  'recalib_H1_phase_8',
#  'recalib_H1_phase_9',
#  'recalib_L1_amplitude_0',
#  'recalib_L1_amplitude_1',
#  'recalib_L1_amplitude_2',
#  'recalib_L1_amplitude_3',
#  'recalib_L1_amplitude_4',
#  'recalib_L1_amplitude_5',
#  'recalib_L1_amplitude_6',
#  'recalib_L1_amplitude_7',
#  'recalib_L1_amplitude_8',
#  'recalib_L1_amplitude_9',
# ...

# %%
total_mass = samples['total_mass']
mass_ratio = samples['mass_ratio']
luminosity_distance = samples ['luminosity_distance']
spin_1x = samples['spin_1x']
spin_1y = samples['spin_1y']
spin_1z = samples['spin_1z']
spin_2x = samples['spin_2x']
spin_2y = samples['spin_2y']
spin_2z = samples['spin_2z']

spin_1magnitude = np.sqrt(spin_1x **2 + spin_1y **2 + spin_1z **2)
spin_2magnitude = np.sqrt(spin_2x **2 + spin_2y **2 + spin_2z **2)

# %%
plt.hist(total_mass, bins=100, density=True)
plt.xlabel('Total Mass')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
plt.hist(mass_ratio, bins=100, density=True)
plt.xlabel('Mass Ratio')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
plt.hist(spin_1magnitude, bins=100, density=True)
plt.xlabel('Spin 1 Magnitude')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
plt.hist(spin_2magnitude, bins=100, density=True)
plt.xlabel('Spin 2 Magnitude')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
plt.hist(luminosity_distance, bins=100, density=True)
plt.xlabel('Luminosity Distance')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
total_mass2 = samples2['total_mass']
mass_ratio2 = samples2['mass_ratio']
luminosity_distance2 = samples2['luminosity_distance']
spin_1x = samples2['spin_1x']
spin_1y = samples2['spin_1y']
spin_1z = samples2['spin_1z']
spin_2x = samples2['spin_2x']
spin_2y = samples2['spin_2y']
spin_2z = samples2['spin_2z']

spin_1magnitude2 = np.sqrt(spin_1x **2 + spin_1y **2 + spin_1z **2)
spin_2magnitude2 = np.sqrt(spin_2x **2 + spin_2y **2 + spin_2z **2)

# %%
total_mass3 = samples3['total_mass']
mass_ratio3 = samples3['mass_ratio']
luminosity_distance3 = samples3['luminosity_distance']
spin_1x = samples3['spin_1x']
spin_1y = samples3['spin_1y']
spin_1z = samples3['spin_1z']
spin_2x = samples3['spin_2x']
spin_2y = samples3['spin_2y']
spin_2z = samples3['spin_2z']

spin_1magnitude3 = np.sqrt(spin_1x **2 + spin_1y **2 + spin_1z **2)
spin_2magnitude3 = np.sqrt(spin_2x **2 + spin_2y **2 + spin_2z **2)

# %%
plt.hist(total_mass, bins=100, density=True, alpha=0.5, label= 'IMRPhenomXPHM')
plt.hist(total_mass2, bins=100, density=True, alpha=0.5, label= 'Mixed')
plt.hist(total_mass3, bins=100, density=True, alpha=0.5, label= 'SEOBNRv4PHM')
plt.legend()
plt.xlabel('Total Mass')
plt.ylabel('Density')
plt.show()

# %%
plt.hist(mass_ratio, bins=100, density=True, alpha=0.5, label= 'IMRPhenomXPHM')
plt.hist(mass_ratio2, bins=100, density=True, alpha=0.5, label= 'Mixed')
plt.hist(mass_ratio3, bins=100, density=True, alpha=0.5, label= 'SEOBNRv4PHM')
plt.legend()
plt.xlabel('Mass Ratio')
plt.ylabel('Density')
plt.show()

# %%
plt.hist(luminosity_distance, bins=100, density=True, alpha=0.5, label= 'IMRPhenmoXPHM')
plt.hist(luminosity_distance2, bins=100, density=True, alpha=0.5, label= 'Mixed')
plt.hist(luminosity_distance3, bins=100, density=True, alpha=0.5, label= 'SEOBNRv4PHM')
plt.legend()
plt.xlabel('Luminosity Distance')
plt.ylabel('Density')
plt.show()

# %%
plt.hist(spin_1magnitude, bins=100, density=True, alpha=0.5, label= 'IMRPhenmoXPHM')
plt.hist(spin_1magnitude2, bins=100, density=True, alpha=0.5, label= 'Mixed')
plt.hist(spin_1magnitude3, bins=100, density=True, alpha=0.5, label= 'SEOBNRv4PHM')
plt.legend()
plt.xlabel('Spin 1 Magnitude')
plt.ylabel('Density')
plt.show()

# %%
plt.hist(spin_2magnitude, bins=100, density=True, alpha=0.5, label= 'IMRPhenmoXPHM')
plt.hist(spin_2magnitude2, bins=100, density=True, alpha=0.5, label= 'Mixed')
plt.hist(spin_2magnitude3, bins=100, density=True, alpha=0.5, label= 'SEOBNRv4PHM')
plt.legend()
plt.xlabel('Spin 2 Magnitude')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')
